# %%
import torch 
x = torch.empty(5, 3) 
print(x)
# Out:
# tensor([[7.8255e+35, 6.0676e-43, 7.8270e+35],
#         [6.0676e-43, 7.8267e+35, 6.0676e-43],
#         [7.8267e+35, 6.0676e-43, 7.8271e+35],
#         [6.0676e-43, 7.8271e+35, 6.0676e-43],
#         [7.8278e+35, 6.0676e-43, 7.8278e+35]])

# %%
# !wget -nc "https://labfile.oss.aliyuncs.com/courses/3205/idiom.txt"
# Out:
# 'wget' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# 需要下载安装 wget.exe   https://eternallybored.org/misc/wget/ 下载地址

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
